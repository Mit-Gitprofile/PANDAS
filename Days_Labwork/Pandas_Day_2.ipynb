# %%
import pandas as pd
from io import StringIO

# Corrected CSV data
csv_data = """Question,Tags,Option-1,Option-2,Option-3,Option-4,Answer
What does NLP stand for?,NLP Basics,Natural Language Processing,Neural Language Processing,Natural Learning Process,Neuro-Linguistic Programming,Natural Language Processing
Why is NLP important?,NLP Basics,To improve human-computer interaction,To replace human translators,To eliminate programming languages,To create artificial intelligence,To improve human-computer interaction
Which of the following is an application of NLP?,NLP Applications,Speech Recognition,Image Processing,Data Mining,Game Development,Speech Recognition
What is the purpose of text preprocessing in NLP?,NLP Pipeline,To improve model accuracy,To reduce computational cost,To make text human-readable,To translate text into another language,To improve model accuracy
Which of the following is NOT a common NLP task?,Common NLP Tasks,Text Classification,Image Recognition,Sentiment Analysis,Machine Translation,Image Recognition
What is the first step in the NLP pipeline?,NLP Pipeline,Data Acquisition,Feature Engineering,Modeling,Text Processing,Data Acquisition
What is the purpose of lowercasing in text processing?,Text Processing,To reduce vocabulary size,To improve readability,To remove stop words,To handle emojis,To reduce vocabulary size
Which of the following is used to remove HTML tags from text?,Text Processing,BeautifulSoup,NLTK,Scikit-learn,TensorFlow,BeautifulSoup
What is the purpose of removing URLs from text?,Text Processing,To reduce noise,To improve readability,To handle emojis,To correct spelling,To reduce noise
Which of the following is a common technique for spelling correction?,Text Processing,Levenshtein Distance,TF-IDF,One Hot Encoding,Bag of Words,Levenshtein Distance
What is the purpose of removing stop words?,Text Processing,To reduce noise,To improve readability,To handle emojis,To correct spelling,To reduce noise
Which of the following is a common technique for tokenization?,Text Processing,Word Tokenization,Sentence Tokenization,Both A and B,None of the above,Both A and B
What is the purpose of stemming in text processing?,Text Processing,To reduce words to their root form,To improve readability,To handle emojis,To correct spelling,To reduce words to their root form
What is the purpose of lemmatization in text processing?,Text Processing,To reduce words to their base or dictionary form,To improve readability,To handle emojis,To correct spelling,To reduce words to their base or dictionary form
What is feature extraction in NLP?,Feature Extraction,The process of converting text into numerical features,The process of translating text,The process of summarizing text,The process of correcting spelling,The process of converting text into numerical features
Why is feature extraction important in NLP?,Feature Extraction,To make text understandable by machine learning models,To improve readability,To handle emojis,To correct spelling,To make text understandable by machine learning models
Which of the following is a common technique for feature extraction?,Feature Extraction,One Hot Encoding,Bag of Words,TF-IDF,All of the above,All of the above
What is One Hot Encoding?,Feature Extraction,A technique to convert categorical variables into binary vectors,A technique to remove stop words,A technique to correct spelling,A technique to handle emojis,A technique to convert categorical variables into binary vectors
What is Bag of Words?,Feature Extraction,A technique to represent text as a vector of word counts,A technique to remove stop words,A technique to correct spelling,A technique to handle emojis,A technique to represent text as a vector of word counts
What are N-grams?,Feature Extraction,A sequence of N words,A technique to remove stop words,A technique to correct spelling,A technique to handle emojis,A sequence of N words
What is the benefit of using N-grams?,Feature Extraction,They capture context and word order,They reduce vocabulary size,They improve readability,They handle emojis,They capture context and word order
What is a disadvantage of using N-grams?,Feature Extraction,They increase the dimensionality of the feature space,They reduce vocabulary size,They improve readability,They handle emojis,They increase the dimensionality of the feature space
What is TF-IDF?,Feature Extraction,A technique to measure the importance of a word in a document,A technique to remove stop words,A technique to correct spelling,A technique to handle emojis,A technique to measure the importance of a word in a document
What are custom features in NLP?,Feature Extraction,Features created based on domain knowledge,Features created by removing stop words,Features created by correcting spelling,Features created by handling emojis,Features created based on domain knowledge
What are word embeddings?,Feature Extraction,A technique to represent words as dense vectors,A technique to remove stop words,A technique to correct spelling,A technique to handle emojis,A technique to represent words as dense vectors
What is Word2Vec?,Feature Extraction,A technique to generate word embeddings,A technique to remove stop words,A technique to correct spelling,A technique to handle emojis,A technique to generate word embeddings
What is the intuition behind Word2Vec?,Feature Extraction,Words appearing in similar contexts have similar meanings,Words appearing in similar contexts have opposite meanings,Words appearing in different contexts have similar meanings,Words appearing in different contexts have opposite meanings,Words appearing in similar contexts have similar meanings
What are the types of Word2Vec architectures?,Feature Extraction,CBOW and Skip-gram,TF-IDF and Bag of Words,One Hot Encoding and N-grams,Stemming and Lemmatization,CBOW and Skip-gram
What is CBOW in Word2Vec?,Feature Extraction,A model that predicts a word given its context,A model that predicts context given a word,A model that removes stop words,A model that corrects spelling,A model that predicts a word given its context
What is Skip-gram in Word2Vec?,Feature Extraction,A model that predicts context given a word,A model that predicts a word given its context,A model that removes stop words,A model that corrects spelling,A model that predicts context given a word
How is a Word2Vec model trained?,Feature Extraction,Using a large corpus of text,Using a small corpus of text,Using images,Using audio files,Using a large corpus of text
What is text classification?,Text Classification,The process of categorizing text into predefined labels,The process of translating text,The process of summarizing text,The process of correcting spelling,The process of categorizing text into predefined labels
What are the types of text classification?,Text Classification,Binary Classification,Multi-class Classification,Multi-label Classification,All of the above,All of the above
What is an application of text classification?,Text Classification,Spam Detection,Image Recognition,Data Mining,Game Development,Spam Detection
What is the pipeline for text classification?,Text Classification,"Data Acquisition, Data Preparation, Feature Engineering, Modeling, Deployment","Data Acquisition, Data Preparation, Feature Engineering, Modeling, Deployment","Data Acquisition, Data Preparation, Feature Engineering, Modeling, Deployment","Data Acquisition, Data Preparation, Feature Engineering, Modeling, Deployment","Data Acquisition, Data Preparation, Feature Engineering, Modeling, Deployment"
What are the different approaches to text classification?,Text Classification,"Heuristic Approach, Using API, BoW and n-grams, TF-IDF, Word2Vec","Heuristic Approach, Using API, BoW and n-grams, TF-IDF, Word2Vec","Heuristic Approach, Using API, BoW and n-grams, TF-IDF, Word2Vec","Heuristic Approach, Using API, BoW and n-grams, TF-IDF, Word2Vec","Heuristic Approach, Using API, BoW and n-grams, TF-IDF, Word2Vec"
What is a heuristic approach to text classification?,Text Classification,Using rule-based methods,Using machine learning models,Using deep learning models,Using statistical methods,Using rule-based methods
What is Parts of Speech (POS) Tagging?,POS Tagging,The process of labeling words with their respective parts of speech,The process of translating text,The process of summarizing text,The process of correcting spelling,The process of labeling words with their respective parts of speech
What is an application of POS Tagging?,POS Tagging,Text-to-Speech Synthesis,Image Recognition,Data Mining,Game Development,Text-to-Speech Synthesis
How does POS Tagging work?,POS Tagging,By using a pre-trained model or rule-based system,By translating text,By summarizing text,By correcting spelling,By using a pre-trained model or rule-based system
What is the purpose of data acquisition in NLP?,NLP Pipeline,To collect raw text data,To preprocess text data,To extract features from text,To train a model,To collect raw text data
What is the purpose of data preparation in NLP?,NLP Pipeline,To clean and preprocess raw text data,To collect raw text data,To extract features from text,To train a model,To clean and preprocess raw text data
What is the purpose of feature engineering in NLP?,NLP Pipeline,To convert text into numerical features,To collect raw text data,To preprocess text data,To train a model,To convert text into numerical features
What is the purpose of modeling in NLP?,NLP Pipeline,To train a machine learning model on text data,To collect raw text data,To preprocess text data,To extract features from text,To train a machine learning model on text data
What is the purpose of deployment in NLP?,NLP Pipeline,To make the model available for use,To collect raw text data,To preprocess text data,To extract features from text,To make the model available for use
What is the purpose of removing punctuation from text?,Text Processing,To reduce noise,To improve readability,To handle emojis,To correct spelling,To reduce noise
What is the purpose of handling emojis in text processing?,Text Processing,To convert emojis into text or remove them,To improve readability,To reduce noise,To correct spelling,To convert emojis into text or remove them
What is the purpose of chat word treatment in text processing?,Text Processing,To normalize informal language,To improve readability,To reduce noise,To correct spelling,To normalize informal language
What is the purpose of spelling correction in text processing?,Text Processing,To correct misspelled words,To improve readability,To reduce noise,To handle emojis,To correct misspelled words
What is the purpose of removing stop words in text processing?,Text Processing,To reduce noise,To improve readability,To handle emojis,To correct spelling,To reduce noise
What is the purpose of tokenization in text processing?,Text Processing,To split text into words or sentences,To improve readability,To reduce noise,To handle emojis,To split text into words or sentences
What is the purpose of stemming in text processing?,Text Processing,To reduce words to their root form,To improve readability,To handle emojis,To correct spelling,To reduce words to their root form
What is the purpose of lemmatization in text processing?,Text Processing,To reduce words to their base or dictionary form,To improve readability,To handle emojis,To correct spelling,To reduce words to their base or dictionary form
What is the purpose of feature extraction in NLP?,Feature Extraction,To convert text into numerical features,To collect raw text data,To preprocess text data,To train a model,To convert text into numerical features
What is the purpose of One Hot Encoding in feature extraction?,Feature Extraction,To convert categorical variables into binary vectors,To remove stop words,To correct spelling,To handle emojis,To convert categorical variables into binary vectors
What is the purpose of Bag of Words in feature extraction?,Feature Extraction,To represent text as a vector of word counts,To remove stop words,To correct spelling,To handle emojis,To represent text as a vector of word counts
What is the purpose of N-grams in feature extraction?,Feature Extraction,To capture context and word order,To remove stop words,To correct spelling,To handle emojis,To capture context and word order
What is the purpose of TF-IDF in feature extraction?,Feature Extraction,To measure the importance of a word in a document,To remove stop words,To correct spelling,To handle emojis,To measure the importance of a word in a document
What is the purpose of custom features in feature extraction?,Feature Extraction,To create features based on domain knowledge,To remove stop words,To correct spelling,To handle emojis,To create features based on domain knowledge
What is the purpose of word embeddings in feature extraction?,Feature Extraction,To represent words as dense vectors,To remove stop words,To correct spelling,To handle emojis,To represent words as dense vectors
What is the purpose of Word2Vec in feature extraction?,Feature Extraction,To generate word embeddings,To remove stop words,To correct spelling,To handle emojis,To generate word embeddings
What is the purpose of CBOW in Word2Vec?,Feature Extraction,To predict a word given its context,To predict context given a word,To remove stop words,To correct spelling,To predict a word given its context
What is the purpose of Skip-gram in Word2Vec?,Feature Extraction,To predict context given a word,To predict a word given its context,To remove stop words,To correct spelling,To predict context given a word
What is the purpose of training a Word2Vec model?,Feature Extraction,To learn word embeddings from a large corpus of text,To remove stop words,To correct spelling,To handle emojis,To learn word embeddings from a large corpus of text
What is the purpose of text classification in NLP?,Text Classification,To categorize text into predefined labels,To translate text,To summarize text,To correct spelling,To categorize text into predefined labels
What is the purpose of binary classification in text classification?,Text Classification,To categorize text into two classes,To categorize text into multiple classes,To summarize text,To correct spelling,To categorize text into two classes
What is the purpose of multi-class classification in text classification?,Text Classification,To categorize text into multiple classes,To categorize text into two classes,To summarize text,To correct spelling,To categorize text into multiple classes
What is the purpose of multi-label classification in text classification?,Text Classification,To assign multiple labels to a single text,To categorize text into two classes,To summarize text,To correct spelling,To assign multiple labels to a single text
What is the purpose of the heuristic approach in text classification?,Text Classification,To use rule-based methods,To use machine learning models,To use deep learning models,To use statistical methods,To use rule-based methods
What is the purpose of using APIs in text classification?,Text Classification,To leverage pre-trained models,To use rule-based methods,To use machine learning models,To use deep learning models,To leverage pre-trained models
What is the purpose of using BoW and n-grams in text classification?,Text Classification,To represent text as numerical features,To use rule-based methods,To use machine learning models,To use deep learning models,To represent text as numerical features
What is the purpose of using TF-IDF in text classification?,Text Classification,To measure the importance of words in a document,To use rule-based methods,To use machine learning models,To use deep learning models,To measure the importance of words in a document
What is the purpose of using Word2Vec in text classification?,Text Classification,To represent words as dense vectors,To use rule-based methods,To use machine learning models,To use deep learning models,To represent words as dense vectors
What is the purpose of POS Tagging in NLP?,POS Tagging,To label words with their respective parts of speech,To translate text,To summarize text,To correct spelling,To label words with their respective parts of speech
What is the purpose of text-to-speech synthesis in POS Tagging?,POS Tagging,To convert text into spoken words,To translate text,To summarize text,To correct spelling,To convert text into spoken words
What is the purpose of using a pre-trained model in POS Tagging?,POS Tagging,To label words with their respective parts of speech,To translate text,To summarize text,To correct spelling,To label words with their respective parts of speech
"""

# Convert CSV string to DataFrame
df = pd.read_csv(StringIO(csv_data))

# Save DataFrame to XLSX file
df.to_excel("nlp_questions.xlsx", index=False, engine="openpyxl")

print("XLSX file saved as 'nlp_questions.xlsx'")
# Out:
# XLSX file saved as 'nlp_questions.xlsx'

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Creating DataFrame

# %%
# using lists
student_data = [
    [100,80,10],
    [90,70,7],
    [120,100,14],
    [80,50,2]
]

pd.DataFrame(student_data,columns=['iq_1','marks','package'] )
# Out:
#    iq_1  marks  package
# 0   100     80       10
# 1    90     70        7
# 2   120    100       14
# 3    80     50        2

# %%
# using dicts

student_dict = {
    'name':['nitish','ankit','rupesh','rishabh','amit','ankita'],
    'iq':[100,90,120,80,0,0],
    'marks':[80,70,100,50,0,0],
    'package':[10,7,14,2,0,0]
}

students = pd.DataFrame(student_dict)
students.set_index('name',inplace=True)
students
# Out:
#           iq  marks  package
# name
# nitish   100     80       10
# ankit     90     70        7
# rupesh   120    100       14
# rishabh   80     50        2
# amit       0      0        0
# ankita     0      0        0

# %%
# using read_csv
movies = pd.read_csv('movies.csv')
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
# movies.to_csv("/movies_demo.csv")

# %%
ipl = pd.read_csv('ipl-matches.csv')
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %% [markdown]
# ### DataFrame Attributes and Methods

# %%
# shape
movies.shape
# Out:
# (1629, 18)

# %%
ipl.shape
# Out:
# (950, 20)

# %%
# dtypes
ipl.dtypes
# Out:
# ID                   int64
# City                object
# Date                object
# Season              object
# MatchNumber         object
# Team1               object
# Team2               object
# Venue               object
# TossWinner          object
# TossDecision        object
# SuperOver           object
# WinningTeam         object
# WonBy               object
# Margin             float64
# method              object
# Player_of_Match     object
# Team1Players        object
# Team2Players        object
# Umpire1             object
# Umpire2             object
# dtype: object

# %%
# dtypes
movies.dtypes
# Out:
# title_x              object
# imdb_id              object
# poster_path          object
# wiki_link            object
# title_y              object
# original_title       object
# is_adult              int64
# year_of_release       int64
# runtime              object
# genres               object
# imdb_rating         float64
# imdb_votes            int64
# story                object
# summary              object
# tagline              object
# actors               object
# wins_nominations     object
# release_date         object
# dtype: object

# %%
# index
movies.index
# Out:
# RangeIndex(start=0, stop=1629, step=1)

# %%
# index
ipl.index
# Out:
# RangeIndex(start=0, stop=950, step=1)

# %%
# columns
movies.columns
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='object')

# %%
# columns
ipl.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
# values
ipl.values[0]
# Out:
# array([1312200, 'Ahmedabad', '2022-05-29', '2022', 'Final',
#        'Rajasthan Royals', 'Gujarat Titans',
#        'Narendra Modi Stadium, Ahmedabad', 'Rajasthan Royals', 'bat', 'N',
#        'Gujarat Titans', 'Wickets', 7.0, nan, 'HH Pandya',
#        "['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D Padikkal', 'SO Hetmyer', 'R Ashwin', 'R Parag', 'TA Boult', 'OC McCoy', 'M Prasidh Krishna', 'YS Chahal']",
#        "['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pandya', 'DA Miller', 'R Tewatia', 'Rashid Khan', 'R Sai Kishore', 'LH Ferguson', 'Yash Dayal', 'Mohammed Shami']",
#        'CB Gaffaney', 'Nitin Menon'], dtype=object)

# %%
# head and tail
movies.head(2)
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
# 1             Battalion 609  tt9472208
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 1             Battalion 609             Battalion 609         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0             2019     138  Action|Drama|War          8.4       35112
# 1             2019     131               War          4.1          73
#
#                                                story  \
# ...

# %%
ipl.tail()
# Out:
#          ID        City        Date   Season MatchNumber  \
# 945  335986     Kolkata  2008-04-20  2007/08           4
# 946  335985      Mumbai  2008-04-20  2007/08           5
# 947  335984       Delhi  2008-04-19  2007/08           3
# 948  335983  Chandigarh  2008-04-19  2007/08           2
# 949  335982   Bangalore  2008-04-18  2007/08           1
#
#                            Team1                        Team2  \
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 945                                Eden Gardens              Deccan Chargers
# 946                            Wankhede Stadium               Mumbai Indians
# ...

# %%
# sample
ipl.sample(5)
# Out:
#           ID       City        Date   Season MatchNumber                Team1  \
# 404   980955     Rajkot  2016-05-01     2016          28        Gujarat Lions
# 149  1216541  Abu Dhabi  2020-10-25  2020/21          45       Mumbai Indians
# 470   829749  Ahmedabad  2015-04-24     2015          22     Rajasthan Royals
# 465   829765    Chennai  2015-04-28     2015          28  Chennai Super Kings
# 181  1216503  Abu Dhabi  2020-10-01  2020/21          13       Mumbai Indians
#
#                            Team2                                   Venue  \
# 404              Kings XI Punjab  Saurashtra Cricket Association Stadium
# 149             Rajasthan Royals                    Sheikh Zayed Stadium
# 470  Royal Challengers Bangalore            Sardar Patel Stadium, Motera
# 465        Kolkata Knight Riders         MA Chidambaram Stadium, Chepauk
# 181              Kings XI Punjab                    Sheikh Zayed Stadium
#
# ...

# %%
# info
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
# describe
movies.describe()
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count    1629.0      1629.000000  1629.000000    1629.000000
# mean        0.0      2010.263966     5.557459    5384.263352
# std         0.0         5.381542     1.567609   14552.103231
# min         0.0      2001.000000     0.000000       0.000000
# 25%         0.0      2005.000000     4.400000     233.000000
# 50%         0.0      2011.000000     5.600000    1000.000000
# 75%         0.0      2015.000000     6.800000    4287.000000
# max         0.0      2019.000000     9.400000  310481.000000

# %%
ipl.describe()
# Out:
#                  ID      Margin
# count  9.500000e+02  932.000000
# mean   8.304852e+05   17.056867
# std    3.375678e+05   21.633109
# min    3.359820e+05    1.000000
# 25%    5.012612e+05    6.000000
# 50%    8.297380e+05    8.000000
# 75%    1.175372e+06   19.000000
# max    1.312200e+06  146.000000

# %%
# isnull
# movies.isnull()
movies.notnull()
# Out:
#       title_x  imdb_id  poster_path  wiki_link  title_y  original_title  \
# 0        True     True         True       True     True            True
# 1        True     True        False       True     True            True
# 2        True     True         True       True     True            True
# 3        True     True         True       True     True            True
# 4        True     True        False       True     True            True
# ...       ...      ...          ...        ...      ...             ...
# 1624     True     True         True       True     True            True
# 1625     True     True         True       True     True            True
# 1626     True     True        False       True     True            True
# 1627     True     True         True       True     True            True
# 1628     True     True         True       True     True            True
#
#       is_adult  year_of_release  runtime  genres  imdb_rating  imdb_votes  \
# ...

# %%
# isnull
movies.isnull().sum()
# Out:
# title_x                0
# imdb_id                0
# poster_path          103
# wiki_link              0
# title_y                0
# original_title         0
# is_adult               0
# year_of_release        0
# runtime                0
# genres                 0
# imdb_rating            0
# imdb_votes             0
# story                 20
# summary                0
# tagline             1072
# actors                 5
# wins_nominations     922
# release_date         107
# dtype: int64

# %%
# duplicated
movies.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1624    False
# 1625    False
# 1626    False
# 1627    False
# 1628    False
# Length: 1629, dtype: bool

# %%
# duplicated
movies.duplicated().sum()
# Out:
# 0

# %%
students.duplicated().sum()
# Out:
# 1

# %%
# rename
students
# Out:
#           iq  marks  package
# name
# nitish   100     80       10
# ankit     90     70        7
# rupesh   120    100       14
# rishabh   80     50        2
# amit       0      0        0
# ankita     0      0        0

# %%
students.rename(columns={'marks':'percent','package':'lpa'},inplace=True)

# %%
students
# Out:
#           iq  percent  lpa
# name
# nitish   100       80   10
# ankit     90       70    7
# rupesh   120      100   14
# rishabh   80       50    2
# amit       0        0    0
# ankita     0        0    0

# %% [markdown]
# ### Math Methods

# %%
# sum -> axis argument
students.sum(axis=0)
# Out:
# iq         390
# percent    300
# lpa         33
# dtype: int64

# %%
students.sum(axis=1)
# Out:
# name
# nitish     190
# ankit      167
# rupesh     234
# rishabh    132
# amit         0
# ankita       0
# dtype: int64

# %%
students.mean(axis=1)
# Out:
# name
# nitish     63.333333
# ankit      55.666667
# rupesh     78.000000
# rishabh    44.000000
# amit        0.000000
# ankita      0.000000
# dtype: float64

# %%
students.var()
# Out:
# iq         2710.0
# percent    1760.0
# lpa          33.5
# dtype: float64

# %% [markdown]
# ### Selecting cols from a DataFrame

# %%
# single cols
movies['title_x']
# Out:
# 0                   Uri: The Surgical Strike
# 1                              Battalion 609
# 2       The Accidental Prime Minister (film)
# 3                            Why Cheat India
# 4                            Evening Shadows
#                         ...
# 1624                   Tera Mera Saath Rahen
# 1625                    Yeh Zindagi Ka Safar
# 1626                         Sabse Bada Sukh
# 1627                                   Daaka
# 1628                                Humsafar
# Name: title_x, Length: 1629, dtype: object

# %%
type(movies['title_x'])
# Out:
# pandas.core.series.Series

# %%
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
ipl['Venue']
# Out:
# 0                Narendra Modi Stadium, Ahmedabad
# 1                Narendra Modi Stadium, Ahmedabad
# 2                           Eden Gardens, Kolkata
# 3                           Eden Gardens, Kolkata
# 4                        Wankhede Stadium, Mumbai
#                           ...
# 945                                  Eden Gardens
# 946                              Wankhede Stadium
# 947                              Feroz Shah Kotla
# 948    Punjab Cricket Association Stadium, Mohali
# 949                         M Chinnaswamy Stadium
# Name: Venue, Length: 950, dtype: object

# %%
# multiple cols
movies[['year_of_release','actors','title_x']]
# Out:
#       year_of_release                                             actors  \
# 0                2019  Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...
# 1                2019  Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...
# 2                2019  Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...
# 3                2019  Emraan Hashmi|Shreya Dhanwanthary|Snighdadeep ...
# 4                2018  Mona Ambegaonkar|Ananth Narayan Mahadevan|Deva...
# ...               ...                                                ...
# 1624             2001  Ajay Devgn|Sonali Bendre|Namrata Shirodkar|Pre...
# 1625             2001  Ameesha Patel|Jimmy Sheirgill|Nafisa Ali|Gulsh...
# 1626             2018  Vijay Arora|Asrani|Rajni Bala|Kumud Damle|Utpa...
# 1627             2019                          Gippy Grewal|Zareen Khan|
# 1628             2011                                        Fawad Khan|
#
#                                    title_x
# 0                 Uri: The Surgical Strike
# ...

# %%
ipl[['Team1','Team2','WinningTeam']]
# Out:
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 4            Sunrisers Hyderabad                 Punjab Kings
# ..                           ...                          ...
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                      WinningTeam
# 0                 Gujarat Titans
# 1               Rajasthan Royals
# 2    Royal Challengers Bangalore
# 3                 Gujarat Titans
# 4                   Punjab Kings
# ...

# %% [markdown]
# ### Selecting rows from a DataFrame
#
# - **iloc** - searches using index positions
# - **loc** - searches using index labels

# %%
# single row
movies.iloc[5]
# Out:
# title_x                                                   Soni (film)
# imdb_id                                                     tt6078866
# poster_path         https://upload.wikimedia.org/wikipedia/en/thum...
# wiki_link                   https://en.wikipedia.org/wiki/Soni_(film)
# title_y                                                          Soni
# original_title                                                   Soni
# is_adult                                                            0
# year_of_release                                                  2018
# runtime                                                            97
# genres                                                          Drama
# imdb_rating                                                       7.2
# imdb_votes                                                       1595
# story               Soni  a young policewoman in Delhi  and her su...
# ...

# %%
# multiple row
movies.iloc[:5]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
# fancy indexing
movies.iloc[[0,4,5]]
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
# 4           Evening Shadows  tt6028796
# 5               Soni (film)  tt6078866
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
# 5  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
# 5          https://en.wikipedia.org/wiki/Soni_(film)
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 4           Evening Shadows           Evening Shadows         0
# 5                      Soni                      Soni         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# ...

# %%
# loc
students
# Out:
#           iq  percent  lpa
# name
# nitish   100       80   10
# ankit     90       70    7
# rupesh   120      100   14
# rishabh   80       50    2
# amit       0        0    0
# ankita     0        0    0

# %%
students.loc["ankita"]
# Out:
# iq         0
# percent    0
# lpa        0
# Name: ankita, dtype: int64

# %%
students.loc['nitish':'rishabh':2]
# Out:
#          iq  percent  lpa
# name
# nitish  100       80   10
# rupesh  120      100   14

# %%
students.loc[['ankita','rupesh']]
# Out:
#          iq  percent  lpa
# name
# ankita    0        0    0
# rupesh  120      100   14

# %%
students.iloc[[0,3,4]]
# Out:
#           iq  percent  lpa
# name
# nitish   100       80   10
# rishabh   80       50    2
# amit       0        0    0

# %% [markdown]
# ### Selecting both rows and cols

# %%
movies.iloc[0:5:2,0:3:]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 2  The Accidental Prime Minister (film)  tt6986710
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN

# %%
movies.loc[0:2,'title_x':'poster_path']
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...

# %% [markdown]
# ### Filtering a DataFrame

# %%
ipl.head(15)
# Out:
#          ID         City        Date Season  MatchNumber  \
# 0   1312200    Ahmedabad  2022-05-29   2022        Final
# 1   1312199    Ahmedabad  2022-05-27   2022  Qualifier 2
# 2   1312198      Kolkata  2022-05-25   2022   Eliminator
# 3   1312197      Kolkata  2022-05-24   2022  Qualifier 1
# 4   1304116       Mumbai  2022-05-22   2022           70
# 5   1304115       Mumbai  2022-05-21   2022           69
# 6   1304114       Mumbai  2022-05-20   2022           68
# 7   1304113       Mumbai  2022-05-19   2022           67
# 8   1304112  Navi Mumbai  2022-05-18   2022           66
# 9   1304111       Mumbai  2022-05-17   2022           65
# 10  1304110  Navi Mumbai  2022-05-16   2022           64
# 11  1304109       Mumbai  2022-05-15   2022           63
# 12  1304108       Mumbai  2022-05-15   2022           62
# 13  1304107         Pune  2022-05-14   2022           61
# 14  1304106       Mumbai  2022-05-13   2022           60
#
# ...

# %%
mask = ipl['MatchNumber'] == 'Qualifier 2'
mask
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 945    False
# 946    False
# 947    False
# 948    False
# 949    False
# Name: MatchNumber, Length: 950, dtype: bool

# %%
# find all the final winners
# mask = ipl['MatchNumber'] == 'Qualifier 2'
# new_df = ipl[mask]
# new_df
# new_df[['Season','WinningTeam']]

# ipl[ipl['MatchNumber'] == 'Final']
ipl[ipl['MatchNumber'] == 'Final'][['Season','WinningTeam']]
# mask
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
# find all the final winners
# mask = ipl['MatchNumber'] == 'Final'
# new_df = ipl[mask]
# new_df[['Season','WinningTeam']]
ipl[ipl['MatchNumber'] == 'Final'][['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
ipl['SuperOver'][ipl['SuperOver'] == 'Y']
# Out:
# 114    Y
# 158    Y
# 159    Y
# 184    Y
# 192    Y
# 203    Y
# 244    Y
# 339    Y
# 474    Y
# 533    Y
# 608    Y
# 621    Y
# 819    Y
# 883    Y
# Name: SuperOver, dtype: object

# %%
# how many super over finishes have occured
ipl[['Season','WinningTeam','SuperOver']][ipl['SuperOver'] == 'Y']
# Out:
#       Season                  WinningTeam SuperOver
# 114     2021               Delhi Capitals         Y
# 158  2020/21        Kolkata Knight Riders         Y
# 159  2020/21              Kings XI Punjab         Y
# 184  2020/21  Royal Challengers Bangalore         Y
# 192  2020/21               Delhi Capitals         Y
# 203     2019               Mumbai Indians         Y
# 244     2019               Delhi Capitals         Y
# 339     2017               Mumbai Indians         Y
# 474     2015              Kings XI Punjab         Y
# 533     2014             Rajasthan Royals         Y
# 608     2013  Royal Challengers Bangalore         Y
# 621     2013          Sunrisers Hyderabad         Y
# 819  2009/10              Kings XI Punjab         Y
# 883     2009             Rajasthan Royals         Y

# %%
# how many super over finishes have occured
ipl[ipl['SuperOver'] == 'Y'].shape
# Out:
# (14, 20)

# %%
ipl[['WinningTeam' , 'City']][(ipl['WinningTeam'] == 'Chennai Super Kings')].count()
# Out:
# WinningTeam    121
# City           114
# dtype: int64

# %%
# how many matches has csk won in kolkata
ipl[['WinningTeam','City']][(ipl['City'] == 'Kolkata') & (ipl['WinningTeam'] == 'Chennai Super Kings')]
# Out:
#              WinningTeam     City
# 224  Chennai Super Kings  Kolkata
# 602  Chennai Super Kings  Kolkata
# 641  Chennai Super Kings  Kolkata
# 827  Chennai Super Kings  Kolkata
# 908  Chennai Super Kings  Kolkata

# %%
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
# how many matches has csk won in kolkata
ipl[(ipl['City'] == 'Kolkata') & (ipl['WinningTeam'] == 'Chennai Super Kings')].shape
# Out:
# (5, 20)

# %%
# toss winner is match winner in percentage
ipl[ipl['TossWinner'] == ipl['WinningTeam']].shape
# Out:
# (489, 20)

# %%
ipl.shape[0]
# Out:
# 950

# %%
489/950*100
# Out:
# 51.473684210526315

# %%
ipl[ipl['TossWinner'] == ipl['WinningTeam']].shape[0]
# Out:
# 489

# %%
# toss winner is match winner in percentage
(ipl[ipl['TossWinner'] == ipl['WinningTeam']].shape[0]/ipl.shape[0])*100
# Out:
# 51.473684210526315

# %%
# movies with rating higher than 8 and votes>10000
movies[(movies['imdb_rating'] > 8) & (movies['imdb_votes'] > 10000)]
# Out:
#                           title_x     imdb_id  \
# 0        Uri: The Surgical Strike   tt8291224
# 11                      Gully Boy   tt2395469
# 37              Article 15 (film)  tt10324144
# 40                Super 30 (film)   tt7485048
# 143                       Tumbbad   tt8239946
# 146                     Andhadhun   tt8108198
# 325              Pink (2016 film)   tt5571734
# 354                 Dangal (film)   tt5074352
# 418                        Masaan   tt4635372
# 426          Drishyam (2015 film)   tt4430212
# 436                 Talvar (film)   tt4934950
# 469             Queen (2014 film)   tt3322420
# 536                 Haider (film)   tt3390572
# 566                   Ugly (film)   tt2882328
# 567                     PK (film)   tt2338151
# 589                  Vishwaroopam   tt2199711
# 612            Bhaag Milkha Bhaag   tt2356180
# 638                 Shahid (film)   tt2181831
# 668       Paan Singh Tomar (film)   tt1620933
# ...

# %%
# movies with rating higher than 8 and votes>10000
movies[(movies['imdb_rating'] > 8) & (movies['imdb_votes'] < 10000)]
# Out:
#                                 title_x     imdb_id  \
# 41                 Family of Thakurganj   tt8897986
# 53                          Section 375   tt8144834
# 58                    Ghost (2019 film)   tt9378950
# 59                     Bala (2019 film)   tt9420648
# 62                       Saand Ki Aankh   tt8108206
# 64                          Ujda Chaman  tt11046300
# 84                            Mukkabaaz   tt7180544
# 192            Sachin: A Billion Dreams   tt4640206
# 207                          G Kutta Se   tt4307132
# 216      Yadvi – The Dignified Princess   tt4910010
# 219                    Raag Desh (film)   tt6080746
# 279                  Nil Battey Sannata   tt5005684
# 1060  Blood Brothers (2007 Indian film)   tt0893395
# 1363                            Maqbool   tt0379370
# 1435         Final Solution (2003 film)   tt0402178
# 1540          War and Peace (2002 film)   tt0311356
# 1628                           Humsafar   tt2403201
#
# ...

# %%
# Action movies with rating higher than 7.5

mask1 = movies['genres'].str.split('|').apply(lambda x:'Action' in x)
mask1 = movies['genres'].str.contains('Action')
mask2 = movies['imdb_rating'] > 7.5

movies[mask1 & mask2]
# Out:
#                             title_x    imdb_id  \
# 0          Uri: The Surgical Strike  tt8291224
# 41             Family of Thakurganj  tt8897986
# 84                        Mukkabaaz  tt7180544
# 106                           Raazi  tt7098658
# 110   Parmanu: The Story of Pokhran  tt6826438
# 112         Bhavesh Joshi Superhero  tt6129302
# 169                The Ghazi Attack  tt6299040
# 219                Raag Desh (film)  tt6080746
# 258                   Irudhi Suttru  tt5310090
# 280                       Laal Rang  tt5600714
# 297                     Udta Punjab  tt4434004
# 354                   Dangal (film)  tt5074352
# 362               Bajrangi Bhaijaan  tt3863552
# 365          Baby (2015 Hindi film)  tt3848892
# 393      Detective Byomkesh Bakshy!  tt3447364
# 449               Titli (2014 film)  tt3019620
# 536                   Haider (film)  tt3390572
# 589                    Vishwaroopam  tt2199711
# 625                     Madras Cafe  tt2855648
# ...

# %% [markdown]
# ### Adding new cols

# %%
# completely new
movies['Country'] = 'India'
movies.head()
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
# from existing ones
movies.dropna(inplace=True)

# %%
movies['lead actor'] = movies['actors'].str.split('|').apply(lambda x:x[0])
movies.head()
# Out:
#               title_x     imdb_id  \
# 11          Gully Boy   tt2395469
# 34      Yeh Hai India   tt5525846
# 37  Article 15 (film)  tt10324144
# 87            Aiyaary   tt6774212
# 96   Raid (2018 film)   tt7363076
#
#                                           poster_path  \
# 11  https://upload.wikimedia.org/wikipedia/en/thum...
# 34  https://upload.wikimedia.org/wikipedia/en/thum...
# 37  https://upload.wikimedia.org/wikipedia/en/thum...
# 87  https://upload.wikimedia.org/wikipedia/en/thum...
# 96  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                           wiki_link        title_y  \
# 11          https://en.wikipedia.org/wiki/Gully_Boy      Gully Boy
# 34      https://en.wikipedia.org/wiki/Yeh_Hai_India  Yeh Hai India
# 37  https://en.wikipedia.org/wiki/Article_15_(film)     Article 15
# 87            https://en.wikipedia.org/wiki/Aiyaary        Aiyaary
# 96   https://en.wikipedia.org/wiki/Raid_(2018_film)           Raid
#
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 298 entries, 11 to 1623
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           298 non-null    object
#  1   imdb_id           298 non-null    object
#  2   poster_path       298 non-null    object
#  3   wiki_link         298 non-null    object
#  4   title_y           298 non-null    object
#  5   original_title    298 non-null    object
#  6   is_adult          298 non-null    int64
#  7   year_of_release   298 non-null    int64
#  8   runtime           298 non-null    object
#  9   genres            298 non-null    object
#  10  imdb_rating       298 non-null    float64
#  11  imdb_votes        298 non-null    int64
#  12  story             298 non-null    object
#  13  summary           298 non-null    object
#  14  tagline           298 non-null    object
#  15  actors            298 non-null    object
# ...

# %% [markdown]
# ### Important DataFrame Functions

# %%
# astype
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
ipl['ID'] = ipl['ID'].astype('int32')

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int32
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
ipl['Season'] = ipl['Season'].astype('category')
ipl['Team1'] = ipl['Team1'].astype('category')
ipl['Team2'] = ipl['Team2'].astype('category')

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int32
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    category
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    category
#  6   Team2            950 non-null    category
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
# value_counts

# %%
# find which player has won most potm -> in finals and qualifiers

# %%
# Toss decision plot

# %%
# how many matches each team has played

# %%
# sort_values -> ascending -> na_position -> inplace -> multiple cols
