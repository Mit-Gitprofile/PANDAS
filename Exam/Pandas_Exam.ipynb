# %%
# %pip install pandas

# %%
#  Pandas Analyzer & Data Visualization  #
#========================================#

# link:-
#https://docs.google.com/document/d/1jKiX-x4LcBLE90X_jQyqKVSm4US865NHuHuLxs-7cZM/edit?tab=t.0

import pandas as pd
import matplotlib.pyplot as plt

class DataframeOperation:       # class for dataframe operations
    def operations(self):
        df=dataframe
        while True:
            print("\n == Dataframe Opefrations ==")
            print("   1. Describe The Dataset")
            print("   2. Find Shape Of Dataset")                        #OPTIONS
            print("   3. Find Column Using iloc")
            print("   4. Find Row Using loc")
            print("   5. Rename Any Column")
            print("   6. Sum Of Two Numerical Value Columns")
            print("   7. Exit\n")
            
            expchoice=input("Enter Your Choice:")
            if expchoice=='1':                                  # describe dataframe
                print("\n== Description of Datasets == \n")
                print(df.describe().to_string())
                
            elif expchoice=='2':                                # shape of data frame
                print("\n== Shape of Datasets == \n")
                print(df.shape,"(Row:Column)")
                
            elif expchoice=='3':                                # find column indexwise
                print("\n== Find Column From Datasets == \n")
                col=int(input(f"Enter Column index from (0 - {len(list(df.columns))}):"))
                if df.columns[col] in list(df.columns):
                    print(f"Column no.:{col}")
                    print(f"Column Name: {df.columns[col]}\n")
                    print(f"{pd.Series(df.iloc[:,col])}")
                else:
                    print(f"\n Column no. {col} not found in dataframe...\n")
                
            elif expchoice=='4':                                # find row indexwise
                print("\n== Find Row From Datasets == \n")
                row=int(input(f"Enter row index from (0 - {df.shape[0]}):"))
                if row <= df.shape[0]:
                    print(f"\nRow No.: {row}\n")
                    print(f"{pd.Series(df.loc[row])}")
                else:
                    print("\n Invelid Row Index...\n")
                
            elif expchoice=='5':                            # rename any column
                print("\n== Rename column == \n")
                print(f"Columns:\n{list(df.columns)}")
                col1=input("Enter column Name to Rename column:")
                
                if col1 in list(df.columns):
                    col2=input(f"Enter Name to Rename column '{col1}':")
                    df.rename(columns={col1:col2},inplace=True)
                    print(f"Rename Successfull... {col1} ---> {col2}")
                else:
                    print("\nColumn Name Not Found in Datasets...\n")
                    
            elif expchoice=='6':                           # sum of two numerical values columns
                print("\n== Sum Of Two Numerical Value Columns == \n")
                column=list(df.select_dtypes(include=['int','float']).columns)
                print(f"Numerical Values Columns:\n",column)
                
                col1=input("Enter First column to sum:")
                col2=input(f"Enter Second column to sum:")
                if col1 and col2 in column:
                    df['Sum_column']=df[col1]+df[col2]
                    print(f"Column : {col1}  +  {col2} ---> Sum_column\n")
                    print(pd.DataFrame({col1:df[col1]  ,  col2:df[col2]  , 'Sum_column':df['Sum_column']}))
                else:
                    print("\nColumn Name Not Found in Datasets...\n")
                    
            elif expchoice=='7':
                break
            else:
                print("\nInvelid  Choice...\n")
                
class MissingFilling:
    def missingfilter(self):
        df=dataframe
        while True:
            print("\n == Handle Missing Data ==")
            print("   1. Display Rows With Missing Values")
            print("   2. Fill Missing Values With Mean")                        #OPTIONS
            print("   3. Drop Rows With Missing Values")
            print("   4. Replace Missing Values With A Specific Values")
            print("   5. Exit\n")
            expchoice=input("Enter Your Choice:")
            Nullcolumn=df.columns[df.isnull().any()]        # find null values columns
            Nullrows=df[df.isnull().any(axis=1)]            # find null values rows
            
            if expchoice=='1':              # null values colummns& rows
                if len(list(Nullcolumn))!=0:
                    print("\nFind None Value columns:\n\n",list(Nullcolumn))
                    print("\nMissing Values Rows:\n\n",Nullrows.to_string())
                else:print("\nNo Missing Values In dataframe...\n")
                    
            elif expchoice=='2':                        # find numerical null values columns and fill using mean values
                if len(list(Nullcolumn))!=0:            
                    column=df.select_dtypes(include=['int','float']).columns[df.select_dtypes(include=['int','float']).isnull().any()]
                    if len(column)==0:
                        print("\nNot Numerical Value column in this data ...\n")
                    else:
                        print("\nNumerical Missing Value columns:\n",list(column))
                        clmn=input ("Enter Column Name To fill Value with Mean value:")
                        if clmn in Nullcolumn:
                            df[clmn].fillna(df[clmn].mean(),inplace=True)
                            print(f"\nMissing Values Fill In {clmn} column with mean values\n")
                        else:
                            print(f"\nInvelid Column name... no Missing Values In this Column...\n")
                else:print("\nNo Missing Values In dataframe...\n")
                        
            elif expchoice=='3':                # drop missing values rows
                if len(list(Nullcolumn))!=0:
                    yn=input("Do you Sure To Drop Rows With Missing Values (yes/no):")
                    if yn.lower() =='yes':
                        df.dropna(inplace=True)
                        print(f"\nMissing Values Rows Drop Successfully...\n")
                    elif yn.lower() == 'no':continue
                    else:print(f"\nInvelid Choice...\n")
                else:print("\nNo Missing Values In dataframe...\n")
                
            elif expchoice=='4':                # fill specific values in missing value columns
                if len(list(Nullcolumn))!=0:
                    print("\nMising Value columns:\n",list(Nullcolumn))
                    clmn=input ("Enter Column Name To fill Value :")
                    if clmn in Nullcolumn:
                        val=input("Enter Value To Fill in Column:")
                        df[clmn].fillna(val,inplace=True)
                        print(f"\nMissing Values Fill In '{clmn}' column with '{val}' values\n")
                    else:
                        print(f"\nInvelid Column name... no Missing Values In this Column...\n")
                else:print("\nNo Missing Values In dataframe...\n")
                
            elif expchoice=='5':break
            else:print("Invelid  Choice...")    
            
class GenerateDescriptive:          # class for descriptive operations
    def descriptiveoperations(self):
        df=dataframe
        while True:
            print("\n == Descriptive Statistics ==")
            print("   1. Find Mean")
            print("   2. Find Median")                      
            print("   3. Find Sum")
            print("   4. Find Standard Devision")
            print("   5. Find Varience")
            print("   6. Exit\n")
            expchoice=input("Enter Your Choice:")
            
            column=list(df.select_dtypes(include=['int','float']).columns)      # find numerical values columns
            if expchoice=='1':
                if len(list(column))!=0:        # mean
                    print("\nNumerical Value columns:\n",list(column))
                    clmn=input ("Enter Column Name To Find Mean value:")
                    df['Mean_column']=df[clmn].mean()
                    print(f"\n\nColumn : {clmn}  ---> Mean_column\n\n")
                    print(pd.DataFrame({clmn:df[clmn]  ,  'Mean_column':df['Mean_column']}))
                    
                else:print("\nNo Numerical Values Columns In dataframe...\n")
                    
            elif expchoice=='2':                # median
                if len(list(column))!=0:
                    print("\nNumerical Value columns:\n",list(column))
                    clmn=input ("Enter Column Name To Find Median value:")
                    df['Median_column']=df[clmn].median()
                    print(f"\n\nColumn : {clmn}  ---> Median_column\n\n")
                    print(pd.DataFrame({clmn:df[clmn]  ,  'Median_column':df['Median_column']}))
                    
                else:print("\nNo Numerical Values Columns In dataframe...\n")  
                        
            elif expchoice=='3':                # sum of wo columns
                if len(list(column))!=0:
                    print("\nNumerical Value columns:\n",list(column))
                    col1=input("Enter First column to sum:")
                    col2=input(f"Enter Second column to sum:")
                    if col1 and col2 in column:
                        df['Sum_column']=df[col1]+df[col2]
                        print(f"\n\nColumn : {col1}  +  {col2} ---> Sum_column\n")
                        print(pd.DataFrame({col1:df[col1]  ,  col2:df[col2]  , 'Sum_column':df['Sum_column']}))
                    else:
                        print("\nColumn Name Not Found in Datasets...\n")
                else:print("\nNo Numerical Values Columns In dataframe...\n")
                
            elif expchoice=='4':                # standard devision
                if len(list(column))!=0:
                    print("\nNumerical Value columns:\n",list(column))
                    clmn=input ("Enter Column Name To Find Standard Devision :")
                    df['std_column']=df[clmn].std()
                    print(f"\n\nColumn : {clmn}  ---> std_column\n\n")
                    print(pd.DataFrame({clmn:df[clmn]  ,  'std_column':df['std_column']}))
                    
                else:print("\nNo Numerical Values Columns In dataframe...\n")
                
            elif expchoice=='5':                # varience
                if len(list(column))!=0:
                    print("\nNumerical Value columns:\n",list(column))
                    clmn=input ("Enter Column Name To Find Varience :")
                    df['varience_column']=df[clmn].std()
                    print(f"\n\nColumn : {clmn}  ---> varience_column\n\n")
                    print(pd.DataFrame({clmn:df[clmn]  ,  'varience_column':df['varience_column']}))
                    
                else:print("\nNo Numerical Values Columns In dataframe...\n")
                
            elif expchoice=='6':break
            else:print("Invelid  Choice...")    
            
class DataVisulization:
    def makingbars(self):
        df=dataframe
        objcolumn=list(df.select_dtypes(include=['object']).columns)        # find object columns
        print("\nAvailable Object Columns:", list(objcolumn))  
        col1 = input("Enter the first object column for visualization: ")
        
        numcolumn=list(df.select_dtypes(include=['int','float']).columns)    # find numerical columns
        print("\nAvailable Numerical Columns:", list(numcolumn)) 
        col2 = input("Enter the second Numerical column for visualization: ")

        if (col1 or col2 )in df.columns:
            while True:
                print("\n == Data Visualization ==")
                print("   1. Bar Plot")
                print("   2. Line plot") 
                print("   3. Pie chart")
                print("   4. Box Plot")
                print("   5. Barh Plot")
                print("   6. Exit\n")
                
                expchoice=input("Enter Your Choice:")
                if expchoice=='1':
                    df[[col1,col2]].value_counts().head(7).plot(kind='bar', color='blue')       # Bar Chart
                elif expchoice=='2':
                    df[[col1,col2]].value_counts().head(7).plot(kind='line', color='green')     # Line Chart
                elif expchoice=='3':
                    df[[col1,col2]].value_counts().head(7).plot(kind='pie', color='red')        # Pie Chart
                elif expchoice=='4':
                    df[[col1,col2]].value_counts().head(7).plot(kind='box', color='blue')       # Box Chart
                elif expchoice=='5':
                    df[[col1,col2]].value_counts().head(7).plot(kind='barh', color='yellow')    # Barh Chart
                elif expchoice=='6':
                    break
                else:
                    print("Invelid  Choice...")
                plt.show()
        else:
            print("\nColumns not Found In Dataframes..\n")
                
obj=DataframeOperation()
mis=MissingFilling()
gen=GenerateDescriptive()
bar=DataVisulization()

print("\n============= Data Analysis & Visulization Programm =============")
while True: 
    print("-----------------------------------------------")    
    print("  Please Select an option:")
    print("-----------------------------------------------")
    print("   1. Load Dataset")
    print("   2. Expplore Data")                        # main options
    print("   3. Perform dataframe Operations")
    print("   4. Handle Missing Data")
    print("   5. Generate Descriptive statistics")
    print("   6. Data Visulization")
    print("   7. Save Chenged Dataframe to Csv")
    print("   8. Exit")
    print("-----------------------------------------------\n")
    

    main_choice=int(input("Enter your choice:"))

    match main_choice:  
    # case 1 for load dataset
        case 1:                     
            print("\n == Load Dataset ==")
            file=input("Enter The path Of the Dataset (CSV File):")    
            dataframe=pd.DataFrame(pd.read_csv(file))               # make dataframe using read csv
            print("Dataset Lodead Successfully!...\n")
        
    # case 2 for explore data
        case 2:
            if 'dataframe' not in locals() or 'dataframe' not in globals() or dataframe.empty:  # dataframe not defineded
                print("\nPlease Select Dataframe Using Option : 1 ...\n")
            else:
                while True:
                    print("\n == Explore Dataset ==")
                    print("   1. Display The First 5 Rows")
                    print("   2. Display The Last 5 Rows")                       
                    print("   3. Display The Column Names")
                    print("   4. Display The Data types")
                    print("   5. Display Besic Info")
                    print("   6. Exit\n")
                    
                    expchoice=input("Enter Your Choice:")
                    if expchoice=='1':                              # first 5 rows
                        print("\nFirst 5 Rows of Datasets:\n")
                        print(dataframe.head(5).to_string())
                    elif expchoice=='2':                              # last 5 rows
                        print("\nLast 5 Rows of Datasets:\n")
                        print(dataframe.tail(5).to_string())
                    elif expchoice=='3':                              # all columns
                        print("\nColumns of Datasets:\n")
                        col=dataframe.columns
                        print(f"{list(col)}\nTotal Columns:{len(list(col))}")
                    elif expchoice=='4':                              # datatypes of columns
                        print("\nData types of Columns:\n")
                        dtp=dataframe.dtypes
                        print(dtp)
                    elif expchoice=='5':                              # info of dataset
                        print("\nInfo of Datasets:\n")
                        print(dataframe.info())
                    elif expchoice=='6':                              
                        break
                    else:
                        print("Invelid  Choice...")
                        
    # case 3 for Perform dataframe Operations 
        case 3:
            if 'dataframe' not in locals() or 'dataframe' not in globals() or dataframe.empty:
                print("\nPlease Select Dataframe Using Option : 1 ...\n")
            else:
                obj.operations()   # call method in class

    # case 4 for Handle missing Data           
        case 4:
            if 'dataframe' not in locals() or 'dataframe' not in globals() or dataframe.empty:
                print("\nPlease Select Dataframe Using Option : 1 ...\n")
            else:
                mis.missingfilter()
     
    # case 5 for descriptive operations       
        case 5:
            if 'dataframe' not in locals() or 'dataframe' not in globals() or dataframe.empty:
                print("\nPlease Select Dataframe Using Option : 1 ...\n")
            else:
                gen.descriptiveoperations()
         
    # case 6 for data visulization  
        case 6:
            if 'dataframe' not in locals() or 'dataframe' not in globals() or dataframe.empty:
                print("\nPlease Select Dataframe Using Option : 1 ...\n")
            else:
                bar.makingbars()
                
                    
    # case 7 for Save Chenged Dataframe to Csv
        case 7:
            if 'dataframe' not in locals() or 'dataframe' not in globals() or dataframe.empty:
                print("\nPlease Select Dataframe Using Option : 1 ...\n")
            else:
                file=input("Enter Filename to save Data (file.csv) with csv formet:")
                if file.endswith('.csv'):
                    dataframe.to_csv(file)
                    print(f"\n file '{file}' saved Succesfull...\n")
                else:
                    print("\nInvelid file Formet .. please enter with .csv Formet...\n")

    # case 8 for breakK
        case 8:
            print("Exiting program...")
            break
# Out:
# ============= Data Analysis & Visulization Programm =============
# -----------------------------------------------
#   Please Select an option:
# -----------------------------------------------
#    1. Load Dataset
#    2. Expplore Data
#    3. Perform dataframe Operations
#    4. Handle Missing Data
#    5. Generate Descriptive statistics
#    6. Data Visulization
#    7. Save Chenged Dataframe to Csv
#    8. Exit
# -----------------------------------------------
#
#
#  == Load Dataset ==
# Dataset Lodead Successfully!...
#
# -----------------------------------------------
#   Please Select an option:
# -----------------------------------------------
#    1. Load Dataset
#    2. Expplore Data
#    3. Perform dataframe Operations
#    4. Handle Missing Data
#    5. Generate Descriptive statistics
#    6. Data Visulization
#    7. Save Chenged Dataframe to Csv
#    8. Exit
# -----------------------------------------------
#
#
#  == Explore Dataset ==
#    1. Display The First 5 Rows
#    2. Display The Last 5 Rows
#    3. Display The Column Names
#    4. Display The Data types
#    5. Display Besic Info
#    6. Exit
#
#
# First 5 Rows of Datasets:
#
#                        Name Platform  Year_of_Release         Genre Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  Critic_Count  User_Score  User_Count Rating
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo     41.36     28.96      3.77         8.45         82.54          76.0          51.0         8.0       324.0      E
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo     29.08      3.58      6.81         0.77         40.24           NaN           NaN         NaN         NaN    NaN
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo     15.68     12.80      3.79         3.29         35.57          82.0          73.0         8.3       712.0      E
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo     15.61     10.95      3.28         2.95         32.78          80.0          73.0         8.0       193.0      E
# 4  Pokemon Red/Pokemon Blue        G           1996.0  Role-Playing  Nintendo     11.27      8.89     10.22         1.00         31.37           NaN           NaN         NaN         NaN    NaN
#
#  == Explore Dataset ==
#    1. Display The First 5 Rows
#    2. Display The Last 5 Rows
#    3. Display The Column Names
#    4. Display The Data types
#    5. Display Besic Info
#    6. Exit
#
#
# First 5 Rows of Datasets:
#
#                        Name Platform  Year_of_Release         Genre Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  Critic_Count  User_Score  User_Count Rating
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo     41.36     28.96      3.77         8.45         82.54          76.0          51.0         8.0       324.0      E
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo     29.08      3.58      6.81         0.77         40.24           NaN           NaN         NaN         NaN    NaN
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo     15.68     12.80      3.79         3.29         35.57          82.0          73.0         8.3       712.0      E
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo     15.61     10.95      3.28         2.95         32.78          80.0          73.0         8.0       193.0      E
# 4  Pokemon Red/Pokemon Blue        G           1996.0  Role-Playing  Nintendo     11.27      8.89     10.22         1.00         31.37           NaN           NaN         NaN         NaN    NaN
#
#  == Explore Dataset ==
#    1. Display The First 5 Rows
#    2. Display The Last 5 Rows
#    3. Display The Column Names
#    4. Display The Data types
#    5. Display Besic Info
#    6. Exit
#
#
# Last 5 Rows of Datasets:
#
#                                                    Name Platform  Year_of_Release       Genre              Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  Critic_Count  User_Score  User_Count Rating
# 17411  Nancy Drew: The Deadly Secret of Olde World Park       DS           2007.0   Adventure  Majesco Entertainment       0.0       0.0      0.00          0.0          0.01          64.0           7.0         NaN         NaN      E
# 17412                      Fashion Designer: Style Icon       DS           2007.0  Simulation              505 Games       0.0       0.0      0.00          0.0          0.01           NaN           NaN         NaN         NaN    NaN
# 17413            Ashita no Joe 2: The Anime Super Remix      PS2           2002.0    Fighting                 Capcom       0.0       0.0      0.01          0.0          0.01           NaN           NaN         NaN         NaN    NaN
# 17414            NadePro!! Kisama no Seiyuu Yatte Miro!      PS2           2009.0   Adventure                 GungHo       0.0       0.0      0.01          0.0          0.01           NaN           NaN         NaN         NaN    NaN
# 17415                     Brian Lara 2007 Pressure Play      PSP           2007.0      Sports            Codemasters       0.0       0.0      0.00          0.0          0.01           NaN           NaN         NaN         NaN    NaN
#
#  == Explore Dataset ==
#    1. Display The First 5 Rows
#    2. Display The Last 5 Rows
#    3. Display The Column Names
#    4. Display The Data types
#    5. Display Besic Info
#    6. Exit
#
#
# Columns of Datasets:
#
# ['Name', 'Platform', 'Year_of_Release', 'Genre', 'Publisher', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'Critic_Score', 'Critic_Count', 'User_Score', 'User_Count', 'Rating']
# Total Columns:15
#
#  == Explore Dataset ==
#    1. Display The First 5 Rows
#    2. Display The Last 5 Rows
#    3. Display The Column Names
#    4. Display The Data types
#    5. Display Besic Info
#    6. Exit
#
#
# Data types of Columns:
#
# Name                object
# Platform            object
# Year_of_Release    float64
# Genre               object
# Publisher           object
# NA_Sales           float64
# EU_Sales           float64
# JP_Sales           float64
# Other_Sales        float64
# Global_Sales       float64
# Critic_Score       float64
# Critic_Count       float64
# User_Score         float64
# User_Count         float64
# Rating              object
# dtype: object
#
#  == Explore Dataset ==
#    1. Display The First 5 Rows
#    2. Display The Last 5 Rows
#    3. Display The Column Names
#    4. Display The Data types
#    5. Display Besic Info
#    6. Exit
#
# -----------------------------------------------
#   Please Select an option:
# -----------------------------------------------
#    1. Load Dataset
#    2. Expplore Data
#    3. Perform dataframe Operations
#    4. Handle Missing Data
#    5. Generate Descriptive statistics
#    6. Data Visulization
#    7. Save Chenged Dataframe to Csv
#    8. Exit
# -----------------------------------------------
#
# Exiting program...
